# %% [markdown]
# <a href="https://www.kaggle.com/code/zlimshady/missing-immigrant-globally-data?scriptVersionId=124322445" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/missing-migrants-globally-from-2022-10-21-to-date/missingmigrants-global-2022-10-21t22-36-040800.xlsx

# %% [markdown]
# ## **Missing Migrants Project**
#
# Missing Migrants Project draws on a range of sources to track deaths of migrants along migratory routes across the globe. Data from this project are published in the report “Fatal Journeys: Tracking Lives Lost during Migration,” which provides the most comprehensive global tally of migrant fatalities for 2014, and estimates deaths over the past 15 years.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
immigrant_df = pd.read_excel('/kaggle/input/missing-migrants-globally-from-2022-10-21-to-date/missingmigrants-global-2022-10-21t22-36-040800.xlsx')

# %% [markdown]
# ## Data Cleaning

# %%
immigrant_df
# Out:
#             Main ID    Incident ID           Region            Incident Date  \
# 0     2022.MMP00001  2022.MMP00001    Mediterranean  Sun, 01/02/2022 - 12:00
# 1     2022.MMP00002  2022.MMP00002    Mediterranean  Mon, 01/03/2022 - 12:00
# 2     2022.MMP00003  2022.MMP00003  Southern Africa  Mon, 01/03/2022 - 12:00
# 3     2022.MMP00004  2022.MMP00004    Mediterranean  Mon, 01/03/2022 - 12:00
# 4     2022.MMP00005  2022.MMP00005    Southern Asia  Sat, 01/01/2022 - 12:00
# ...             ...            ...              ...                      ...
# 1235   2022.MMP1209   2022.MMP1209   Eastern Africa  Tue, 10/18/2022 - 12:00
# 1236   2022.MMP1210   2022.MMP1210  Central America  Tue, 10/18/2022 - 12:00
# 1237   2022.MMP1211   2022.MMP1211  Central America  Wed, 10/19/2022 - 12:00
# 1238   2022.MMP1212   2022.MMP1212  Northern Africa  Wed, 10/12/2022 - 12:00
# 1239   2022.MMP1213   2022.MMP1213    Mediterranean  Thu, 10/13/2022 - 12:00
#
# ...

# %%
#We can view some basic information about the data frame using the .info method.

immigrant_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1240 entries, 0 to 1239
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Main ID                              1240 non-null   object
#  1   Incident ID                          1240 non-null   object
#  2   Region                               1240 non-null   object
#  3   Incident Date                        1240 non-null   object
#  4   Year                                 1240 non-null   int64
#  5   Reported Month                       1240 non-null   object
#  6   Number Dead                          1140 non-null   float64
#  7   Minimum Estimated Number of Missing  177 non-null    float64
#  8   Total Number of Dead and Missing     1240 non-null   int64
#  9   Number of Survivors                  287 non-null    float64
#  10  Number of Females                    219 non-null    float64
# ...

# %%
# It appears that each column contains values of a specific data type. You can view statistical information for numerical columns (mean, standard deviation, minimum/maximum values, and the number of non-empty values) using the .describe method.

immigrant_df.describe()
# Out:
#          Year  Number Dead  Minimum Estimated Number of Missing  \
# count  1240.0  1140.000000                           177.000000
# mean   2022.0     1.849123                            10.254237
# std       0.0     3.847174                            13.200714
# min    2022.0     0.000000                             0.000000
# 25%    2022.0     1.000000                             2.000000
# 50%    2022.0     1.000000                             5.000000
# 75%    2022.0     1.000000                            14.000000
# max    2022.0   102.000000                            96.000000
#
#        Total Number of Dead and Missing  Number of Survivors  \
# count                       1240.000000           287.000000
# mean                           3.163710            33.515679
# std                            7.500969            73.218365
# min                            1.000000             0.000000
# 25%                            1.000000             4.500000
# ...

# %%
#The columns property contains the list of columns within the data frame.

immigrant_df.columns
# Out:
# Index(['Main ID', 'Incident ID', 'Region', 'Incident Date', 'Year',
#        'Reported Month', 'Number Dead', 'Minimum Estimated Number of Missing',
#        'Total Number of Dead and Missing', 'Number of Survivors',
#        'Number of Females', 'Number of Males', 'Number of Children',
#        'Cause of Death', 'Location of death', 'Information Source',
#        'Coordinates', 'Migrantion route', 'URL', 'UNSD Geographical Grouping',
#        'Source Quality'],
#       dtype='object')

# %% [markdown]
# We can use the .head and .tail methods to view the first or last few rows of data.

# %%
immigrant_df.head(5)
# Out:
#          Main ID    Incident ID           Region            Incident Date  \
# 0  2022.MMP00001  2022.MMP00001    Mediterranean  Sun, 01/02/2022 - 12:00
# 1  2022.MMP00002  2022.MMP00002    Mediterranean  Mon, 01/03/2022 - 12:00
# 2  2022.MMP00003  2022.MMP00003  Southern Africa  Mon, 01/03/2022 - 12:00
# 3  2022.MMP00004  2022.MMP00004    Mediterranean  Mon, 01/03/2022 - 12:00
# 4  2022.MMP00005  2022.MMP00005    Southern Asia  Sat, 01/01/2022 - 12:00
#
#    Year Reported Month  Number Dead  Minimum Estimated Number of Missing  \
# 0  2022        January          1.0                                  NaN
# 1  2022        January          3.0                                  8.0
# 2  2022        January          3.0                                  3.0
# 3  2022        January          3.0                                 14.0
# 4  2022        January          1.0                                  NaN
#
#    Total Number of Dead and Missing  Number of Survivors  ...  \
# ...

# %%
immigrant_df.tail(5)
# Out:
#            Main ID   Incident ID           Region            Incident Date  \
# 1235  2022.MMP1209  2022.MMP1209   Eastern Africa  Tue, 10/18/2022 - 12:00
# 1236  2022.MMP1210  2022.MMP1210  Central America  Tue, 10/18/2022 - 12:00
# 1237  2022.MMP1211  2022.MMP1211  Central America  Wed, 10/19/2022 - 12:00
# 1238  2022.MMP1212  2022.MMP1212  Northern Africa  Wed, 10/12/2022 - 12:00
# 1239  2022.MMP1213  2022.MMP1213    Mediterranean  Thu, 10/13/2022 - 12:00
#
#       Year Reported Month  Number Dead  Minimum Estimated Number of Missing  \
# 1235  2022        October         25.0                                  NaN
# 1236  2022        October          3.0                                  NaN
# 1237  2022        October          1.0                                  NaN
# 1238  2022        October          NaN                                 22.0
# 1239  2022        October          2.0                                  5.0
#
# ...

# %%
# Dropping all rows that are not useful in the analysis 

immigrant_df.drop(['Main ID','Incident ID','Location of death','Information Source','Coordinates','Migrantion route','URL','UNSD Geographical Grouping','Source Quality'], axis = 1, inplace = True)

# %%
immigrant_df
# Out:
#                Region            Incident Date  Year Reported Month  \
# 0       Mediterranean  Sun, 01/02/2022 - 12:00  2022        January
# 1       Mediterranean  Mon, 01/03/2022 - 12:00  2022        January
# 2     Southern Africa  Mon, 01/03/2022 - 12:00  2022        January
# 3       Mediterranean  Mon, 01/03/2022 - 12:00  2022        January
# 4       Southern Asia  Sat, 01/01/2022 - 12:00  2022        January
# ...               ...                      ...   ...            ...
# 1235   Eastern Africa  Tue, 10/18/2022 - 12:00  2022        October
# 1236  Central America  Tue, 10/18/2022 - 12:00  2022        October
# 1237  Central America  Wed, 10/19/2022 - 12:00  2022        October
# 1238  Northern Africa  Wed, 10/12/2022 - 12:00  2022        October
# 1239    Mediterranean  Thu, 10/13/2022 - 12:00  2022        October
#
#       Number Dead  Minimum Estimated Number of Missing  \
# 0             1.0                                  NaN
# ...

# %%
# Checks for null Values, Returns Boolean Array

pd.isnull(immigrant_df)
# Out:
#       Region  Incident Date   Year  Reported Month  Number Dead  \
# 0      False          False  False           False        False
# 1      False          False  False           False        False
# 2      False          False  False           False        False
# 3      False          False  False           False        False
# 4      False          False  False           False        False
# ...      ...            ...    ...             ...          ...
# 1235   False          False  False           False        False
# 1236   False          False  False           False        False
# 1237   False          False  False           False        False
# 1238   False          False  False           False         True
# 1239   False          False  False           False        False
#
#       Minimum Estimated Number of Missing  Total Number of Dead and Missing  \
# 0                                    True                             False
# ...

# %%
# Replaces all null values with 0

immigrant_df = immigrant_df.fillna(0)
immigrant_df
# Out:
#                Region            Incident Date  Year Reported Month  \
# 0       Mediterranean  Sun, 01/02/2022 - 12:00  2022        January
# 1       Mediterranean  Mon, 01/03/2022 - 12:00  2022        January
# 2     Southern Africa  Mon, 01/03/2022 - 12:00  2022        January
# 3       Mediterranean  Mon, 01/03/2022 - 12:00  2022        January
# 4       Southern Asia  Sat, 01/01/2022 - 12:00  2022        January
# ...               ...                      ...   ...            ...
# 1235   Eastern Africa  Tue, 10/18/2022 - 12:00  2022        October
# 1236  Central America  Tue, 10/18/2022 - 12:00  2022        October
# 1237  Central America  Wed, 10/19/2022 - 12:00  2022        October
# 1238  Northern Africa  Wed, 10/12/2022 - 12:00  2022        October
# 1239    Mediterranean  Thu, 10/13/2022 - 12:00  2022        October
#
#       Number Dead  Minimum Estimated Number of Missing  \
# 0             1.0                                  0.0
# ...

# %%
# method of retrieve a random sample of rows from the data frame.

immigrant_df.sample(10)
# Out:
#               Region            Incident Date  Year Reported Month  \
# 454           Europe  Wed, 05/11/2022 - 12:00  2022            May
# 338    North America  Sat, 02/19/2022 - 12:00  2022       February
# 269    Southern Asia  Sun, 01/30/2022 - 12:00  2022        January
# 308    North America  Mon, 03/21/2022 - 12:00  2022          March
# 578  Central America  Mon, 05/16/2022 - 12:00  2022            May
# 353        Caribbean  Thu, 04/07/2022 - 12:00  2022          April
# 231    Southern Asia  Tue, 01/04/2022 - 12:00  2022        January
# 339    North America  Thu, 03/31/2022 - 12:00  2022          March
# 483    Southern Asia  Sun, 04/03/2022 - 12:00  2022          April
# 384  Central America  Fri, 04/15/2022 - 12:00  2022          April
#
#      Number Dead  Minimum Estimated Number of Missing  \
# 454          1.0                                  0.0
# 338          1.0                                  0.0
# 269          1.0                                  0.0
# ...

# %%
#renaming the columns

immigrant_df = immigrant_df.rename(columns={'Incident Date': 'Incident_Date', 'Reported Month' : 'Reported_Month', 'Number Dead' : 'Number_Dead', 'Minimum Estimated Number of Missing' : 'Minimum_Estimated_Number_of_Missing', 'Total Number of Dead and Missing' : 'Total Number_of_Dead_and_Missing', 'Number of Survivors' : 'Number_of_Survivors', 'Number of Females' : 'Number_of_Females', 'Number of Males' : 'Number_of_Males', 'Number of Children' : 'Number_of_Children', 'Cause of Death' : 'Cause_of_Death' })

# %%
immigrant_df
# Out:
#                Region            Incident_Date  Year Reported_Month  \
# 0       Mediterranean  Sun, 01/02/2022 - 12:00  2022        January
# 1       Mediterranean  Mon, 01/03/2022 - 12:00  2022        January
# 2     Southern Africa  Mon, 01/03/2022 - 12:00  2022        January
# 3       Mediterranean  Mon, 01/03/2022 - 12:00  2022        January
# 4       Southern Asia  Sat, 01/01/2022 - 12:00  2022        January
# ...               ...                      ...   ...            ...
# 1235   Eastern Africa  Tue, 10/18/2022 - 12:00  2022        October
# 1236  Central America  Tue, 10/18/2022 - 12:00  2022        October
# 1237  Central America  Wed, 10/19/2022 - 12:00  2022        October
# 1238  Northern Africa  Wed, 10/12/2022 - 12:00  2022        October
# 1239    Mediterranean  Thu, 10/13/2022 - 12:00  2022        October
#
#       Number_Dead  Minimum_Estimated_Number_of_Missing  \
# 0             1.0                                  0.0
# ...

# %% [markdown]
# The data type of date is currently object, so Pandas does not know that this column is a date. We can convert it into a datetime column using the pd.to_datetime method.

# %% [markdown]
# You can see that it now has the datatype datetime64. We can now extract different parts of the data into separate columns, using the DatetimeIndex class

# %% [markdown]
# ## **Writing data back to files**
#
# After completing your data sorting, cleaning, transformnation and adding new columns, you should write the results back to a file. Let us first create a data frame containing just the columns we wish to record.

# %%
immigrant_df.to_csv('missing_immigrant.csv', index=None)
